# %% [markdown]
# # This is a program to merge the current dataset and an oncoming one

# %%
import json

# %%
with open("data/data.json", "r", encoding="utf-8") as f1:
    data1 = json.load(f1)

with open("data/new_data.json", "r", encoding="utf-8") as f2:
    data2 = json.load(f2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 with open("data/old_data.json", "r", encoding="utf-8") as f1:
#       2     data1 = json.load(f1)
#       4 with open("data/new_data.json", "r", encoding="utf-8") as f2:
#
# File ~/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/old_data.json'

# %%
# Combine datasets
combined = data1 + data2

# Deduplicate based on (text, sorted_entities)
seen = set()
deduped = []
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Combine datasets
# ----> 2 combined = data1 + data2
#       4 # Deduplicate based on (text, sorted_entities)
#       5 seen = set()
#
# NameError: name 'data1' is not defined

# %%
for item in combined:
    text, annotations = item
    # Sort entities for consistent comparison
    sorted_entities = tuple(sorted(tuple(e) for e in annotations["entities"]))
    identifier = (text, sorted_entities)

    if identifier not in seen:
        seen.add(identifier)
        deduped.append((text, annotations))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 for item in combined:
#       2     text, annotations = item
#       3     # Sort entities for consistent comparison
#
# NameError: name 'combined' is not defined

# %%
# Save to a new JSON file
with open("data/data.json", "w", encoding="utf-8") as f:
    json.dump(deduped, f, indent=4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Save to a new JSON file
# ----> 2 with open("data/merged_training_data.json", "w", encoding="utf-8") as f:
#       3     json.dump(deduped, f, indent=4)
#
# File ~/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/merged_training_data.json'

# %%
print(f"Merged training data saved to 'merged_training_data.json' with {len(deduped)} unique examples.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(f"Merged training data saved to 'merged_training_data.json' with {len(deduped)} unique examples.")
#
# NameError: name 'deduped' is not defined
